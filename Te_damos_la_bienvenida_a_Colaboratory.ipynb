# %% [markdown]
# <a href="https://colab.research.google.com/github/paucaroscanoa/ApiBookAuthor/blob/master/Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
api_token= {"username":"mariopaucar","key":"5c783298c60c003e081d228a25f7fff2"}

# %%
# !rm -rf /root/.kaggle.

# %%
# !mkdir /root/.kaggle

# %%
import json
with open('/root/.kaggle/kaggle.json','w') as file:
  json.dump(api_token,file)

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                            title                                           size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# rahulvyasm/netflix-movies-and-tv-shows                         Netflix Movies and TV Shows                      1MB  2024-04-10 09:48:38          21581        474  1.0
# jainaru/world-happiness-report-2024-yearly-updated             World Happiness Report- 2024                    62KB  2024-05-15 19:04:34           1820         35  1.0
# sahirmaharajj/school-student-daily-attendance                  School Student Daily Attendance                  2MB  2024-04-29 19:29:56           5689        118  1.0
# ...

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c home-credit-credit-risk-model-stability
# Out:
# ...
#  99% 3.12G/3.14G [00:26<00:00, 247MB/s]
# 100% 3.14G/3.14G [00:26<00:00, 127MB/s]

# %%
import zipfile

archivo_zip='/content/home-credit-credit-risk-model-stability.zip'

with zipfile.ZipFile(archivo_zip,'r') as zip_file:
  for nombre_archivo in zip_file.namelist():
    print(nombre_archivo)
# Out:
# csv_files/test/test_applprev_1_0.csv
# csv_files/test/test_applprev_1_1.csv
# csv_files/test/test_applprev_1_2.csv
# csv_files/test/test_applprev_2.csv
# csv_files/test/test_base.csv
# csv_files/test/test_credit_bureau_a_1_0.csv
# csv_files/test/test_credit_bureau_a_1_1.csv
# csv_files/test/test_credit_bureau_a_1_2.csv
# csv_files/test/test_credit_bureau_a_1_3.csv
# csv_files/test/test_credit_bureau_a_1_4.csv
# csv_files/test/test_credit_bureau_a_2_0.csv
# csv_files/test/test_credit_bureau_a_2_1.csv
# csv_files/test/test_credit_bureau_a_2_10.csv
# csv_files/test/test_credit_bureau_a_2_11.csv
# csv_files/test/test_credit_bureau_a_2_2.csv
# csv_files/test/test_credit_bureau_a_2_3.csv
# csv_files/test/test_credit_bureau_a_2_4.csv
# csv_files/test/test_credit_bureau_a_2_5.csv
# csv_files/test/test_credit_bureau_a_2_6.csv
# csv_files/test/test_credit_bureau_a_2_7.csv
# csv_files/test/test_credit_bureau_a_2_8.csv
# csv_files/test/test_credit_bureau_a_2_9.csv
# ...

# %%
import pandas as pd

nombre_archivo_csv="csv_files/test/test_applprev_1_1.csv"

with zipfile.ZipFile(archivo_zip,'r') as zip_file:
  with zip_file.open(nombre_archivo_csv) as nombre_archivo_csv:
      dataframe_csv= pd.read_csv(nombre_archivo_csv)

# %%
dataframe_csv.head()
# Out:
#    case_id  actualdpd_943P  annuity_853A approvaldate_319D  \
# 0    57549             0.0           0.0               NaN
# 1    57549             0.0           0.0        2021-10-12
# 2    57549             0.0           0.0        2021-08-18
# 3    57549             0.0           0.0               NaN
# 4    57549             0.0        2024.8        2016-08-07
#
#    byoccupationinc_3656910L cancelreason_3545846M  childnum_21L  \
# 0                       NaN           P94_109_143           NaN
# 1                       NaN              a55475b1           NaN
# 2                       NaN              a55475b1           NaN
# 3                       NaN           P94_109_143           NaN
# 4                       NaN              a55475b1           NaN
#
#   creationdate_885D  credacc_actualbalance_314A  credacc_credlmt_575A  ...  \
# 0        2018-05-05                     34066.0               34066.0  ...
# ...
